# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/TopoGAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/topogat-code

# %%
# Clone your SourceForge repo
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# Change directory into the cloned repo
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 624, done.
# remote: Counting objects: 100% (624/624), done.
# remote: Compressing objects: 100% (584/584), done.
# remote: Total 624 (delta 332), reused 0 (delta 0)
# Receiving objects: 100% (624/624), 3.19 MiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (332/332), done.
# /content/topogat-code

# %%
# Install required packages
# !pip install -r requirements.txt -q


# Optional: Kill the runtime to cleanly reload all dependencies
import os
os.kill(os.getpid(), 9)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 130.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.4 MB/s eta 0:00:00
# ...

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# !cd /content/topogat-code

# %% [markdown]
# # Experiments for MUTAG

# %%
# Navigate to main project directory again (after runtime restart)

# !python graph-tasks/topogat_evaluation.py MUTAG --variant basic
# Out:
# Running experiment on MUTAG with variant 'basic'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/MUTAG/basic
# [INFO] Evaluating for TOPOGAT variant basic
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84        16
#            1       0.87      0.91      0.89        22
#
#     accuracy                           0.87        38
#    macro avg       0.87      0.86      0.86        38
# weighted avg       0.87      0.87      0.87        38
#
# [INFO] Done evaluating for TOPOGAT variant basic
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant node_aware
# Out:
# Running experiment on MUTAG with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/MUTAG/node_aware
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        16
#            1       0.72      0.95      0.82        22
#
#     accuracy                           0.76        38
#    macro avg       0.81      0.73      0.73        38
# weighted avg       0.79      0.76      0.75        38
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant gated
# Out:
# Running experiment on MUTAG with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/MUTAG/gated
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79        16
#            1       0.81      0.95      0.88        22
#
#     accuracy                           0.84        38
#    macro avg       0.86      0.82      0.83        38
# weighted avg       0.85      0.84      0.84        38
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant attn
# Out:
# Running experiment on MUTAG with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/MUTAG/attn
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# weighted avg       0.70      0.68      0.66        38
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# ...

# %% [markdown]
# # Experiments for PROTEINS

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant basic
# Out:
# Running experiment on PROTEINS with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant node_aware
# Out:
# Running experiment on PROTEINS with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PROTEINS/node_aware
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.86      0.77       137
#            1       0.65      0.42      0.51        86
#
#     accuracy                           0.69       223
#    macro avg       0.68      0.64      0.64       223
# weighted avg       0.68      0.69      0.67       223
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.84      0.75       137
#            1       0.58      0.35      0.43        86
#
#     accuracy                           0.65       223
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant gated
# Out:
# Running experiment on PROTEINS with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PROTEINS/gated
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       137
#            1       0.64      0.50      0.56        86
#
#     accuracy                           0.70       223
#    macro avg       0.68      0.66      0.67       223
# weighted avg       0.69      0.70      0.69       223
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.87      0.74       137
#            1       0.55      0.26      0.35        86
#
#     accuracy                           0.63       223
#    macro avg       0.60      0.56      0.55       223
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant attn
# Out:
# Running experiment on PROTEINS with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PROTEINS/attn
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.85      0.78       137
#            1       0.67      0.48      0.56        86
#
#     accuracy                           0.71       223
#    macro avg       0.70      0.67      0.67       223
# weighted avg       0.70      0.71      0.70       223
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73       137
#            1       0.54      0.41      0.46        86
#
#     accuracy                           0.64       223
#    macro avg       0.61      0.59      0.59       223
# ...

# %% [markdown]
# # Experiments for PTC_MR

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant basic
# Out:
# Running experiment on PTC_MR with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PTC_MR/basic
# [INFO] Evaluating for TOPOGAT variant basic
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.51      0.56        39
#            1       0.47      0.57      0.52        30
#
#     accuracy                           0.54        69
#    macro avg       0.54      0.54      0.54        69
# weighted avg       0.55      0.54      0.54        69
#
# [INFO] Done evaluating for TOPOGAT variant basic
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        39
#            1       0.43      0.30      0.35        30
#
#     accuracy                           0.52        69
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant node_aware
# Out:
# Running experiment on PTC_MR with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PTC_MR/node_aware
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.44      0.52        39
#            1       0.48      0.67      0.56        30
#
#     accuracy                           0.54        69
#    macro avg       0.55      0.55      0.54        69
# weighted avg       0.56      0.54      0.53        69
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.69      0.64        39
#            1       0.48      0.37      0.42        30
#
#     accuracy                           0.55        69
#    macro avg       0.53      0.53      0.53        69
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant gated
# Out:
# Running experiment on PTC_MR with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PTC_MR/gated
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.56      0.56        39
#            1       0.41      0.40      0.41        30
#
#     accuracy                           0.49        69
#    macro avg       0.48      0.48      0.48        69
# weighted avg       0.49      0.49      0.49        69
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59        39
#            1       0.47      0.47      0.47        30
#
#     accuracy                           0.54        69
#    macro avg       0.53      0.53      0.53        69
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant attn
# Out:
# Running experiment on PTC_MR with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/PTC_MR/attn
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62        39
#            1       0.50      0.47      0.48        30
#
#     accuracy                           0.57        69
#    macro avg       0.55      0.55      0.55        69
# weighted avg       0.56      0.57      0.56        69
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GAT
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.46      0.52        39
#            1       0.46      0.60      0.52        30
#
#     accuracy                           0.52        69
#    macro avg       0.53      0.53      0.52        69
# ...

# %% [markdown]
# # Experiments for ENZYMES

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant basic
# Out:
# Running experiment on ENZYMES with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Distance matrix contains inf. Returning zero topo vector.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant node_aware
# Out:
# Running experiment on ENZYMES with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/ENZYMES/node_aware
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.05      0.09        19
#            1       0.20      0.25      0.22        20
#            2       0.29      0.33      0.31        18
#            3       0.25      0.09      0.13        22
#            4       0.67      0.09      0.16        22
#            5       0.20      0.63      0.30        19
#
#     accuracy                           0.23       120
#    macro avg       0.32      0.24      0.20       120
# weighted avg       0.33      0.23      0.20       120
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GAT
#
# Classification Report:
#
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant gated
# Out:
# Running experiment on ENZYMES with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/ENZYMES/gated
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant attn
# Out:
# Running experiment on ENZYMES with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat/ENZYMES/attn
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.16      0.16      0.16        19
#            1       0.22      0.20      0.21        20
#            2       0.29      0.44      0.35        18
#            3       0.15      0.09      0.11        22
#            4       0.00      0.00      0.00        22
#            5       0.28      0.58      0.37        19
#
#     accuracy                           0.23       120
#    macro avg       0.18      0.25      0.20       120
# weighted avg       0.18      0.23      0.19       120
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GAT
#
# Classification Report:
#
# ...

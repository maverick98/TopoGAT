# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/topology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧹 Step 1: Clean up and re-create /content if needed
import os
try:
    os.chdir("/content")
except FileNotFoundError:
    os.mkdir("/content")
    os.chdir("/content")

# 🧹 Step 2: Remove any half-cloned folder
# !rm -rf /content/topogat-code

# ✅ Step 3: Now clone cleanly
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# ✅ Step 4: Change into the cloned directory
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 4599, done.
# remote: Counting objects: 100% (4599/4599), done.
# remote: Compressing objects: 100% (4528/4528), done.
# remote: Total 4599 (delta 985), reused 3056 (delta 10)
# Receiving objects: 100% (4599/4599), 65.65 MiB | 46.17 MiB/s, done.
# Resolving deltas: 100% (985/985), done.
# /content/topogat-code

# %%
# ⬇️ 2. Install dependencies
# !pip install -r requirements.txt

# %%
import os
os.kill(os.getpid(), 9)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# !cd /content/topogat-code

# %%
import sys
import os

# Set the project root directory (one level above 'utils/')
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)  # Insert at start

# Change directory to root
os.chdir(ROOT_DIR)

# Try import
from utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Logger is working fine!")
# Out:
# [2025-08-11 17:58:04,643] __main__ - INFO - Logger is working fine!
# INFO:__main__:Logger is working fine!

# %%
import sys
import os

ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
import sys
sys.path.append("/content/topogat-code")
os.chdir(ROOT_DIR)
# ✅ Use %run instead of !python

# %%
#%run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-concat --runs 10
#%run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-node_aware --runs 10
#%run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-gated --runs 10
#%run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-attn --runs 10
#%run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-transformer --runs 10

# %%
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-concat --force_train_eval 0    --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-node_aware --force_train_eval 0  --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-gated --force_train_eval 0  --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-attn  --force_train_eval 0  --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --variant topogat-transformer --force_train_eval 0  --runs 10
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# Checking if training and evaluation required or not?
# Training and Evaluation not required
# Run MANOVA analysis now...
# [INFO] Results will be saved in: /content/drive/MyDrive/topology/results/topogat/MUTAG/topogat-concat
# [INFO] Running MANOVA analysis on /content/drive/MyDrive/topology/results/topogat/MUTAG/topogat-concat/all_metrics/MUTAG_topogat-concat.csv
# [INFO] Results will be saved in: /content/drive/MyDrive/topology/results/topogat/MUTAG/topogat-concat
#
# 🔍 Loading dataset: /content/drive/MyDrive/topology/results/topogat/MUTAG/topogat-concat/all_metrics/MUTAG_topogat-concat.csv
# ✔️ Dependent variables for MANOVA: ['accuracy', 'precision', 'recall', 'f1', 'roc_auc', 'log_loss']
# multivariate_normality = HZResults(hz=0.8326252280259422, pval=0.2500920547137061, normal=True)
# ...

# %%
# %run experiments/topogat_vs_gat.py --dataset MUTAG  --final_report 0 --force_train_eval 0

# %%
# Remove old installs first
# !pip uninstall -y torch torchvision torchaudio torch_geometric torch_scatter torch_sparse transformers safetensors

# Install PyTorch first (CUDA 11.8 example — change for your GPU)
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2 --index-url https://download.pytorch.org/whl/cu118

# Install PyTorch Geometric and deps
# !pip install torch_geometric==2.5.3 torch_scatter==2.1.2 torch_sparse==0.6.18 -f https://data.pyg.org/whl/torch-2.2.2+cu118.html

# Install transformers that works with this torch
# !pip install transformers==4.39.3 safetensors==0.4.2

# %%
# !pip install numpy==1.26.4

# %%
# !cat /content/drive/MyDrive/topology/results/topogat/MUTAG/final_dataset_winner_report.txt
# Out:
# # 🧪 Final Evaluation Summary — Dataset: MUTAG
# ## 🏁 Model Comparison Summary
#
# | Model | Wins | Accuracy | Precision | Recall | F1 | Roc_auc | Log_loss |
# |-------|------|----|----|----|----|----|----|
# | GAT | 1 | 0.7611 | 0.7522 | 0.6867 | 0.6949 | 0.8032 | 0.525 |
# | topogat-attn | 1 | 0.8605 | 0.8608 | 0.8316 | 0.8348 | 0.9573 | 0.2738 |
# | topogat-concat | 1 | 0.8368 | 0.8406 | 0.7899 | 0.7981 | 0.9392 | 0.3398 |
# | topogat-gated | 1 | 0.8605 | 0.8601 | 0.8263 | 0.8315 | 0.9596 | 0.2828 |
# | topogat-node_aware | 1 | 0.8447 | 0.8405 | 0.8072 | 0.8167 | 0.9403 | 0.299 |
# | topogat-transformer | 0 | 0.6737 | 0.3368 | 0.5 | 0.4018 | 0.5204 | 0.6363 |
#
# ## 🏆 Final Verdict
# Tie in wins. Based on higher average accuracy, **topogat-gated** is the best model overall.

# %%
#%run experiments/topogat_vs_gat.py --dataset PTC_MR  --variant topogat-concat --runs 10
# %run experiments/topogat_vs_gat.py --dataset PTC_MR  --variant topogat-node_aware --runs 10
#%run experiments/topogat_vs_gat.py --dataset PTC_MR  --variant topogat-gated --runs 10
#%run experiments/topogat_vs_gat.py --dataset PTC_MR  --variant topogat-attn --runs 10
#%run experiments/topogat_vs_gat.py --dataset PTC_MR  --variant topogat-transformer --runs 10
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'PTC_MR'}
# Checking if training and evaluation required or not?
# Starting Training and Evaluation...
# [INFO] -----------------START-------------------
# [INFO] Starting evaluation for seed 0
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'PTC_MR'}
# [2025-08-05 00:47:53,875] utils.logger - INFO - Initialized TopologyProcessor with max_dim=1, topo_dim=8
# INFO:utils.logger:Initialized TopologyProcessor with max_dim=1, topo_dim=8
# ...
# Extracting data/PTC_MR/PTC_MR/PTC_MR.zip
# Processing...
# Done!
# [2025-08-05 00:47:54,406] datasets.graph_dataset - INFO - Saved PH features to data/PTC_MR/ph_topo.pt
# ...

# %%
# %run experiments/topogat_vs_gat.py --dataset PTC_MR  --final_report 1 --force_train_eval 0
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'PTC_MR'}
# Checking if training and evaluation required or not?
# Training and Evaluation not required
# Evaluating final report...
# [INFO] Final dataset-level winner report written to: /content/drive/MyDrive/topology/results/topogat/PTC_MR/final_dataset_winner_report.txt

# %%
# %run experiments/topogat_vs_gat.py --dataset ENZYMES  --variant topogat-concat --runs 10
# %run experiments/topogat_vs_gat.py --dataset ENZYMES  --variant topogat-node_aware --runs 10
# %run experiments/topogat_vs_gat.py --dataset ENZYMES  --variant topogat-gated --runs 10
# %run experiments/topogat_vs_gat.py --dataset ENZYMES  --variant topogat-attn --runs 10
# %run experiments/topogat_vs_gat.py --dataset ENZYMES  --variant topogat-transformer --runs 10

# %%
#%run experiments/topogat_vs_gat.py --dataset PROTEINS  --variant topogat-concat --runs 10
#%run experiments/topogat_vs_gat.py --dataset PROTEINS  --variant topogat-node_aware --runs 10
#%run experiments/topogat_vs_gat.py --dataset PROTEINS  --variant topogat-gated --runs 10
#%run experiments/topogat_vs_gat.py --dataset PROTEINS  --variant topogat-attn --runs 10
# %run experiments/topogat_vs_gat.py --dataset PROTEINS  --variant topogat-transformer --runs 10

# %%
import sys
import os

ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
import sys
sys.path.append("/content/topogat-code")
os.chdir(ROOT_DIR)
# ✅ Use %run instead of !python
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /content/topogat-code/experiments/topogin_vs_gin.py in <module>
#       1 import argparse
# ----> 2 from models.gin import BaseGIN
#       3 from models.topogin_selector import get_topogin_model
#       4 from experiments.base_experiment import BaseTopoComparisonExperiment
#       5 from experiments.experiment_utils import ExperimentRunnerMixin
#
# /content/topogat-code/models/__init__.py in <module>
#       1 # models/__init__.py
#       2 # 🔁 Ensure decorators in these files run and register models
# ----> 3 from models import topogat  # <-- this will register TopoGAT variants
#       4 from models import topogin  # <-- this will register TopoGIN variants
#       5
#
# /content/topogat-code/models/topogat.py in <module>
#       2 import torch
#       3 import torch.nn.functional as F
# ...

# %%
# %run experiments/topogin_vs_gin.py --dataset MUTAG  --variant topogin-attn --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG  --variant topogin-node_aware --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG  --variant topogin-gated --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG  --variant topogin-concat --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG  --variant topogin-transformer --runs 10
# Out:
# usage: topogin_vs_gin.py [-h] --dataset DATASET [--final_report {0,1}]
#                          [--force_train_eval {0,1}] [--variant VARIANT]
#                          [--runs RUNS] [--use_wandb]
# topogin_vs_gin.py: error: argument --final_report: invalid choice: '0' (choose from 0, 1)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/argparse.py", line 1919, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/argparse.py", line 2140, in _parse_known_args
#     start_index = consume_optional(start_index)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/argparse.py", line 2080, in consume_optional
#     take_action(action, args, option_string)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -R /content/topogat-code/results/MUTAG/all_metrics /content/drive/MyDrive/topology/results/topogin/

# %%
# !pip install scikit-bio

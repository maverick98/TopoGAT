# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/topology.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧹 Step 1: Clean up and re-create /content if needed
import os
try:
    os.chdir("/content")
except FileNotFoundError:
    os.mkdir("/content")
    os.chdir("/content")

# 🧹 Step 2: Remove any half-cloned folder
# !rm -rf /content/topogat-code

# ✅ Step 3: Now clone cleanly
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# ✅ Step 4: Change into the cloned directory
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 4495, done.
# remote: Counting objects: 100% (4495/4495), done.
# remote: Compressing objects: 100% (4424/4424), done.
# remote: Total 4495 (delta 909), reused 3056 (delta 10)
# Receiving objects: 100% (4495/4495), 65.63 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (909/909), done.
# /content/topogat-code

# %%
# ⬇️ 2. Install dependencies
# !pip install -r requirements.txt

# %%
import os
os.kill(os.getpid(), 9)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# !cd /content/topogat-code

# %%
import sys
import os

# Set the project root directory (one level above 'utils/')
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)  # Insert at start

# Change directory to root
os.chdir(ROOT_DIR)

# Try import
from utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Logger is working fine!")
# Out:
# [2025-08-03 05:37:30,182] __main__ - INFO - Logger is working fine!
# INFO:__main__:Logger is working fine!

# %%
import sys
import os

ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
import sys
sys.path.append("/content/topogat-code")
os.chdir(ROOT_DIR)
# ✅ Use %run instead of !python

# %%
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --variant topogat-node_aware --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --variant topogat-gated --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --variant topogat-attn --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --variant topogat-transformer --runs 10
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --variant topogat-concat --runs 10
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# Checking if training and evaluation required or not?
# Starting Training and Evaluation...
# [INFO] -----------------START-------------------
# [INFO] Starting evaluation for seed 0
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# [2025-08-03 05:37:41,680] utils.logger - INFO - Initialized TopologyProcessor with max_dim=1, topo_dim=8
# INFO:utils.logger:Initialized TopologyProcessor with max_dim=1, topo_dim=8
# ...
# Extracting data/MUTAG/MUTAG/MUTAG.zip
# Processing...
# Done!
# [2025-08-03 05:37:43,483] datasets.graph_dataset - INFO - Saved PH features to data/MUTAG/ph_topo.pt
# ...

# %%
import sys
import os

ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
import sys
sys.path.append("/content/topogat-code")
os.chdir(ROOT_DIR)
# ✅ Use %run instead of !python
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# Checking if training and evaluation required or not?
# Starting Training and Evaluation...
# [INFO] -----------------START-------------------
# [INFO] Starting evaluation for seed 0
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# [2025-08-03 04:22:51,164] utils.logger - INFO - Initialized TopologyProcessor with max_dim=1, topo_dim=8
# INFO:utils.logger:Initialized TopologyProcessor with max_dim=1, topo_dim=8
# ...
# Extracting data/MUTAG/MUTAG/MUTAG.zip
# Processing...
# Done!
# [2025-08-03 04:22:52,840] datasets.graph_dataset - INFO - Saved PH features to data/MUTAG/ph_topo.pt
# ...

# %%
# %run experiments/topogin_vs_gin.py --dataset MUTAG --model topogin --variant topogin-node_aware --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG --model topogin --variant topogin-gated --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG --model topogin --variant topogin-attn --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG --model topogin --variant topogin-transformer --runs 10
# %run experiments/topogin_vs_gin.py --dataset MUTAG --model topogin --variant topogin-concat --runs 10
# Out:
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# Checking if training and evaluation required or not?
# Starting Training and Evaluation...
# [INFO] -----------------START-------------------
# [INFO] Starting evaluation for seed 0
# [INFO ] config = {'input_dim': 7, 'topo_dim': 8, 'hidden_dim': 64, 'num_classes': 2, 'heads': 1, 'dropout': 0.2, 'learning_rate': 0.005, 'weight_decay': 0.0005, 'epochs': 200, 'dataset': 'MUTAG'}
# [2025-08-03 04:27:54,188] utils.logger - INFO - Initialized TopologyProcessor with max_dim=1, topo_dim=8
# INFO:utils.logger:Initialized TopologyProcessor with max_dim=1, topo_dim=8
# [2025-08-03 04:27:54,193] datasets.graph_dataset - INFO - Loaded cached PH features from data/MUTAG/ph_topo.pt
# INFO:datasets.graph_dataset:Loaded cached PH features from data/MUTAG/ph_topo.pt
# ...

# %%
# !pip install scikit-bio

# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/topogat_mutag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧹 Step 1: Clean up and re-create /content if needed
import os
try:
    os.chdir("/content")
except FileNotFoundError:
    os.mkdir("/content")
    os.chdir("/content")

# 🧹 Step 2: Remove any half-cloned folder
# !rm -rf /content/topogat-code

# ✅ Step 3: Now clone cleanly
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# ✅ Step 4: Change into the cloned directory
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 4273, done.
# remote: Counting objects: 100% (4273/4273), done.
# remote: Compressing objects: 100% (4202/4202), done.
# remote: Total 4273 (delta 742), reused 3056 (delta 10)
# Receiving objects: 100% (4273/4273), 65.60 MiB | 39.99 MiB/s, done.
# Resolving deltas: 100% (742/742), done.
# /content/topogat-code

# %%
# ⬇️ 2. Install dependencies
# !pip install -q -r requirements.txt

# %%
import os
os.kill(os.getpid(), 9)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# !cd /content/topogat-code

# %%
import sys
import os

# Set the project root directory (one level above 'utils/')
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)  # Insert at start

# Change directory to root
os.chdir(ROOT_DIR)

# Try import
from utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Logger is working fine!")
# Out:
# [2025-08-02 01:33:26,430] __main__ - INFO - Logger is working fine!
# INFO:__main__:Logger is working fine!

# %%
import sys
import os

ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.insert(0, ROOT_DIR)
import sys
sys.path.append("/content/topogat-code")
os.chdir(ROOT_DIR)
# ✅ Use %run instead of !python
# %run experiments/topogat_vs_gat.py --dataset MUTAG --model topogat --runs 10

# %%
# ✅ 5. Run the MANOVA pipeline after training
#!python scripts/run_manova_pipeline.py --dataset MUTAG --arch topogat
# Out:
# Traceback (most recent call last):
#   File "/content/topogat-code/scripts/run_manova_pipeline.py", line 6, in <module>
#     from metrics.manova_runner import run_full_manova_analysis
# ModuleNotFoundError: No module named 'metrics'

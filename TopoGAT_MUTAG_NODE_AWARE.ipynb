# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/TopoGAT_MUTAG_NODE_AWARE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/topogat-code

# %%
# Clone your SourceForge repo
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# Change directory into the cloned repo
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 450, done.
# remote: Counting objects: 100% (450/450), done.
# remote: Compressing objects: 100% (424/424), done.
# remote: Total 450 (delta 236), reused 0 (delta 0)
# Receiving objects: 100% (450/450), 3.16 MiB | 5.93 MiB/s, done.
# Resolving deltas: 100% (236/236), done.
# /content/topogat-code

# %%
# Install required packages
# !pip install -r requirements.txt -q


# Optional: Kill the runtime to cleanly reload all dependencies
import os
os.kill(os.getpid(), 9)
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# %%
# !cd /content/topogat-code

# %%
# Navigate to main project directory again (after runtime restart)

#!python graph-tasks/topogat_evaluation.py MUTAG --variant basic
# !python graph-tasks/topogat_evaluation.py MUTAG --variant node_aware
# Out:
# Running experiment on MUTAG with variant 'node_aware'
# [Topo] Loaded cached PH features from data/MUTAG/ph_topo.pt
# [INFO] Detected topo vector dimension: 9
#
# [Training TopoGAT-node_aware (Seed 0)]
# Epoch 1, Loss: 3.3722
# Epoch 10, Loss: 2.3279
# Epoch 20, Loss: 2.1687
# Epoch 30, Loss: 2.4119
# Epoch 40, Loss: 2.2161
# Epoch 50, Loss: 2.2812
# Epoch 60, Loss: 2.1903
# Epoch 70, Loss: 2.2174
# Epoch 80, Loss: 2.0702
# Epoch 90, Loss: 2.0505
# Epoch 100, Loss: 1.6337
# TopoGAT-node_aware (Seed 0) Test Accuracy: 0.8158
#
# [Training GAT (Seed 0)]
# Epoch 1, Loss: 3.0827
# Epoch 10, Loss: 2.3423
# Epoch 20, Loss: 2.2900
# Epoch 30, Loss: 2.3480
# Epoch 40, Loss: 2.3760
# Epoch 50, Loss: 2.3267
# Epoch 60, Loss: 2.3222
# Epoch 70, Loss: 2.3203
# Epoch 80, Loss: 2.2802
# Epoch 90, Loss: 2.3480
# Epoch 100, Loss: 2.3173
# GAT (Seed 0) Test Accuracy: 0.6842
# [Topo] Loaded cached PH features from data/MUTAG/ph_topo.pt
# [INFO] Detected topo vector dimension: 9
#
# ...

# %%
from IPython.display import Image
Image("/content/topogat-code/mutag_topogat_node_aware_vs_gat.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/accuracy_per_seed_MUTAG.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/confusion_matrix_seed_0_MUTAG.png")

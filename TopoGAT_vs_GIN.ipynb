# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/TopoGAT_vs_GIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/topogat-code

# %%
# Clone your SourceForge repo
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# Change directory into the cloned repo
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 652, done.
# remote: Counting objects: 100% (652/652), done.
# remote: Compressing objects: 100% (608/608), done.
# remote: Total 652 (delta 346), reused 0 (delta 0)
# Receiving objects: 100% (652/652), 3.20 MiB | 10.36 MiB/s, done.
# Resolving deltas: 100% (346/346), done.
# /content/topogat-code

# %%
# Install required packages
# !pip install -r requirements.txt -q


# Optional: Kill the runtime to cleanly reload all dependencies
import os
os.kill(os.getpid(), 9)
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip list | grep -iE 'torch|scikit|geometric|gudhi|yaml|wandb|unittest2|matplotlib|networkx|numpy'
# Out:
# gudhi                                 3.11.0
# matplotlib                            3.10.0
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# networkx                              3.5
# numpy                                 2.0.2
# PyYAML                                6.0.2
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# torch                                 2.6.0+cu124
# torch-geometric                       2.6.1
# torchao                               0.10.0
# torchaudio                            2.6.0+cu124
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.21.0+cu124
# unittest2                             1.1.0
# wandb                                 0.20.1

# %%
#!cd /content/topogat-code
#!rm -rf /content/wheels

# %%
#!mkdir /content/wheels
#!pip download -r requirements.txt -d /content/wheels
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# !cd /content/topogat-code

# %% [markdown]
# # Experiments for MUTAG

# %%
# Navigate to main project directory again (after runtime restart)

# !python graph-tasks/topogat_evaluation.py MUTAG --variant basic --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on MUTAG with variant 'basic'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/MUTAG/basic_vs_gin
# [INFO] Evaluating for TOPOGAT variant basic
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84        16
#            1       0.87      0.91      0.89        22
#
#     accuracy                           0.87        38
#    macro avg       0.87      0.86      0.86        38
# weighted avg       0.87      0.87      0.87        38
#
# [INFO] Done evaluating for TOPOGAT variant basic
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        16
#            1       0.86      0.86      0.86        22
#
#     accuracy                           0.84        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant node_aware --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on MUTAG with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/MUTAG/node_aware_vs_gin
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        16
#            1       0.72      0.95      0.82        22
#
#     accuracy                           0.76        38
#    macro avg       0.81      0.73      0.73        38
# weighted avg       0.79      0.76      0.75        38
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87        16
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.89        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant gated --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on MUTAG with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/MUTAG/gated_vs_gin
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79        16
#            1       0.81      0.95      0.88        22
#
#     accuracy                           0.84        38
#    macro avg       0.86      0.82      0.83        38
# weighted avg       0.85      0.84      0.84        38
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.87        16
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.89        38
# ...

# %%
# !python graph-tasks/topogat_evaluation.py MUTAG --variant attn --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on MUTAG with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/MUTAG/attn_vs_gin
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50        16
#            1       0.67      0.91      0.77        22
#
#     accuracy                           0.68        38
#    macro avg       0.71      0.64      0.63        38
# weighted avg       0.70      0.68      0.66        38
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        16
#            1       0.83      0.91      0.87        22
#
#     accuracy                           0.84        38
# ...

# %% [markdown]
# # Experiments for PROTEINS

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant basic --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PROTEINS with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant node_aware --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PROTEINS with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PROTEINS/node_aware_vs_gin
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78       137
#            1       0.66      0.51      0.58        86
#
#     accuracy                           0.71       223
#    macro avg       0.69      0.67      0.68       223
# weighted avg       0.70      0.71      0.70       223
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       137
#            1       0.61      0.56      0.58        86
#
#     accuracy                           0.69       223
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant gated --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PROTEINS with variant 'gated'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PROTEINS --variant attn --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PROTEINS with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PROTEINS/attn_vs_gin
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.84      0.78       137
#            1       0.67      0.51      0.58        86
#
#     accuracy                           0.71       223
#    macro avg       0.70      0.68      0.68       223
# weighted avg       0.71      0.71      0.70       223
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.75       137
#            1       0.61      0.62      0.61        86
#
#     accuracy                           0.70       223
# ...

# %% [markdown]
# # Experiments for PTC_MR

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant basic --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PTC_MR with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PTC_MR/basic_vs_gin
# [INFO] Evaluating for TOPOGAT variant basic
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.51      0.56        39
#            1       0.47      0.57      0.52        30
#
#     accuracy                           0.54        69
#    macro avg       0.54      0.54      0.54        69
# weighted avg       0.55      0.54      0.54        69
#
# [INFO] Done evaluating for TOPOGAT variant basic
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.54      0.57        39
#            1       0.47      0.53      0.50        30
#
#     accuracy                           0.54        69
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant node_aware --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PTC_MR with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PTC_MR/node_aware_vs_gin
# [INFO] Evaluating for TOPOGAT variant node_aware
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.26      0.35        39
#            1       0.43      0.73      0.54        30
#
#     accuracy                           0.46        69
#    macro avg       0.49      0.49      0.45        69
# weighted avg       0.50      0.46      0.43        69
#
# [INFO] Done evaluating for TOPOGAT variant node_aware
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.49      0.54        39
#            1       0.47      0.60      0.53        30
#
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant gated --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PTC_MR with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PTC_MR/gated_vs_gin
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.72      0.63        39
#            1       0.42      0.27      0.33        30
#
#     accuracy                           0.52        69
#    macro avg       0.49      0.49      0.48        69
# weighted avg       0.50      0.52      0.50        69
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54        39
#            1       0.37      0.33      0.35        30
#
#     accuracy                           0.46        69
# ...

# %%
# !python graph-tasks/topogat_evaluation.py PTC_MR --variant attn --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on PTC_MR with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/PTC_MR/attn_vs_gin
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.62        39
#            1       0.50      0.47      0.48        30
#
#     accuracy                           0.57        69
#    macro avg       0.55      0.55      0.55        69
# weighted avg       0.56      0.57      0.56        69
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GIN
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.56      0.58        39
#            1       0.47      0.50      0.48        30
#
#     accuracy                           0.54        69
# ...

# %% [markdown]
# # Experiments for ENZYMES

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant basic --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on ENZYMES with variant 'basic'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Distance matrix contains inf. Returning zero topo vector.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant node_aware --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on ENZYMES with variant 'node_aware'
# [INFO] Starting evaluation for seed 0
# ...
# Processing...
# Done!
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Distance matrix contains inf. Returning zero topo vector.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# Graph not connected. Extracting largest connected component.
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant gated --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on ENZYMES with variant 'gated'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/ENZYMES/gated_vs_gin
# [INFO] Evaluating for TOPOGAT variant gated
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.11      0.16        19
#            1       0.38      0.25      0.30        20
#            2       0.33      0.33      0.33        18
#            3       0.16      0.23      0.19        22
#            4       0.00      0.00      0.00        22
#            5       0.26      0.63      0.36        19
#
#     accuracy                           0.25       120
#    macro avg       0.24      0.26      0.22       120
# weighted avg       0.24      0.25      0.22       120
#
# [INFO] Done evaluating for TOPOGAT variant gated
# [INFO] Evaluating for GIN
#
# Classification Report:
#
# ...

# %%
# !python graph-tasks/topogat_evaluation.py ENZYMES --variant attn --base gin
# Out:
# Running  TopoGATvsGINExperiment experiment on ENZYMES with variant 'attn'
# [INFO] Starting evaluation for seed 0
# [INFO] Results will be saved in: /content/drive/MyDrive/topogat_vs_gin/ENZYMES/attn_vs_gin
# [INFO] Evaluating for TOPOGAT variant attn
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.33      0.05      0.09        19
#            1       0.22      0.35      0.27        20
#            2       0.20      0.44      0.28        18
#            3       0.21      0.32      0.25        22
#            4       0.00      0.00      0.00        22
#            5       0.67      0.32      0.43        19
#
#     accuracy                           0.24       120
#    macro avg       0.27      0.25      0.22       120
# weighted avg       0.26      0.24      0.22       120
#
# [INFO] Done evaluating for TOPOGAT variant attn
# [INFO] Evaluating for GIN
#
# Classification Report:
#
# ...

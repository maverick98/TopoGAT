# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/TopoGAT/blob/master/TopoGAT_PROTEINS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/topogat-code

# %%
# Clone your SourceForge repo
# !git clone https://msahu98@git.code.sf.net/p/topogat/code topogat-code

# Change directory into the cloned repo
# %cd topogat-code
# Out:
# Cloning into 'topogat-code'...
# remote: Enumerating objects: 321, done.
# remote: Counting objects: 100% (321/321), done.
# remote: Compressing objects: 100% (299/299), done.
# remote: Total 321 (delta 165), reused 0 (delta 0)
# Receiving objects: 100% (321/321), 1.35 MiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/topogat-code

# %%
# Install required packages
# !pip install -r requirements.txt -q


# Optional: Kill the runtime to cleanly reload all dependencies
import os
os.kill(os.getpid(), 9)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.7 MB/s eta 0:00:00
# ...

# %%
import sys
import os

# Ensure the root path is in sys.path
ROOT_DIR = '/content/topogat-code'
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)

# %%
# !cd /content/topogat-code

# %%
# Navigate to main project directory again (after runtime restart)

#!python graph-tasks/main_graph.py
# !python graph-tasks/topogat_evaluation.py PROTEINS
# Out:
# Running experiment on PROTEINS
# ...
# Processing...
# Done!
# [Topo] Saved PH features to data/PROTEINS/ph_topo.pt
# [INFO] Detected topo vector dimension: 9
#
# [Training TopoGAT (Seed 0)]
# Epoch 1, Loss: 21.8493
# Epoch 10, Loss: 17.0056
# Epoch 20, Loss: 16.9707
# Epoch 30, Loss: 16.7022
# Epoch 40, Loss: 16.2175
# Epoch 50, Loss: 16.3506
# Epoch 60, Loss: 16.2223
# Epoch 70, Loss: 16.4082
# Epoch 80, Loss: 16.2339
# Epoch 90, Loss: 16.0572
# Epoch 100, Loss: 15.8310
# TopoGAT (Seed 0) Test Accuracy: 0.7085
#
# [Training GAT (Seed 0)]
# Epoch 1, Loss: 18.9544
# Epoch 10, Loss: 18.4264
# Epoch 20, Loss: 18.3646
# Epoch 30, Loss: 18.3964
# Epoch 40, Loss: 18.4158
# Epoch 50, Loss: 18.4094
# Epoch 60, Loss: 18.3713
# Epoch 70, Loss: 18.3932
# Epoch 80, Loss: 18.4323
# Epoch 90, Loss: 18.4320
# Epoch 100, Loss: 18.3980
# GAT (Seed 0) Test Accuracy: 0.6233
# [Topo] Loaded cached PH features from data/PROTEINS/ph_topo.pt
# [INFO] Detected topo vector dimension: 9
#
# ...

# %%
from IPython.display import Image
Image("/content/topogat-code/topogat_vs_gat_comparison_PROTEINS.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/accuracy_per_seed_PROTEINS.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/confusion_matrix_seed_0_PROTEINS.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/f1-score_per_seed_PROTEINS.png")

# %%
from IPython.display import Image
Image("/content/topogat-code/recall_per_seed_PROTEINS.png")
